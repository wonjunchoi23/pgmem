# %%
print('''
{"call_type": "call_6_qa", "system_prompt": "You are a helpful assistant answering a question about a multi-session conversation between two named speakers, based on memory.\n\nNode types:\n  State:  A speaker-specific condition that is currently or recently valid and may change over time. It captures the speaker's present stance, ongoing goal, constraint, situation, or preference shift. States are time-bounded and context-sensitive.\n  Trait:  A generalized speaker characteristic that persists across situations and time. It represents recurring dispositions, stable preferences, values, or habitual tendencies. Traits are cross-situational and relatively context-independent.\n  Memory: An episodic summary of what happened during a recent conversation. It captures concrete events, topics, and actions at a particular time, not generalized speaker attributes.\n\nEach retrieved item is annotated with an absolute date (e.g. \"[8 May 2023]\") indicating when it was observed in the conversation.", "user_prompt": "[Question]\nWhat writing classes has Maria taken?\n\n[Retrieved Memory]\n[Current Constraints]\n(These are high-impact speaker states the assistant should honor in the response, unless the question explicitly overrides them.)\n[22 July 2023] Maria expresses enthusiasm for John's suggestion of joining a new class.\n[2 April 2023] Maria is engaged in a poetry class to express her feelings.\n[28 January 2023] Maria is inspired by her aunt's belief in volunteering and wants to make a difference.\n[17 December 2022] Maria expresses admiration for John's involvement in improving schools and students' lives.\n[22 July 2023] Maria expresses interest in trying new classes to switch up her exercise routine.\n[7 July 2023] Maria is committed to joining the meeting and contributing to making their community better.\n\n[Traits]\n[5 August 2023] Maria is consistently involved in community service, volunteering at a homeless shelter and organizing events to support veterans and military families. She is passionate about making a positive impact on her community and is deeply committed to kindness and compassion.\n[6 March 2023] Maria is deeply involved in community service, particularly volunteering at a homeless shelter, and is passionate about making a positive impact on others through compassion and connection.\n[31 July 2023] Maria is passionate about connecting with others, finding joy in nature, and making a positive impact in her community through volunteering and activism. She values support, teamwork, and the importance of small acts of kindness that contribute to a larger purpose.\n[5 July 2023] Maria is passionate about volunteering and helping others, often sharing her experiences and the impact of her efforts. She values kindness and compassion, especially in supporting her family and community. Her support for others and her commitment to making a difference are evident in her conversations and actions.\n[18 April 2023] Maria is consistently focused on helping others, volunteering at a homeless shelter, and making a positive impact through her work. She values community, kindness, and connection, often sharing how these efforts bring her joy and fulfillment.\n[17 July 2023] Maria is consistently showing a strong commitment to community improvement, volunteering, and fostering connections through shared activities. She actively participates in community meetings, contributes to making the community better, and enjoys spending time with friends and family in casual, fun settings.\n\n[Relevant States]\n(Additional retrieved speaker states pertaining to the current question; not necessarily high-impact.)\n[25 February 2023] Maria is sharing her recent experience with a creative writing class.\n[25 February 2023] John thanks Maria for the heads up on the creative writing class.\n[2 April 2023] Maria is discussing her recent poetry class experience.\n[5 February 2023] Maria expresses admiration for John's initiative and asks about the inspiration behind it.\n[9 January 2023] Maria mentions her notebook and notes about local politics.\n[20 May 2023] Maria expresses admiration for John's work and acknowledges its value.\n[20 May 2023] Maria supports John's project and encourages his efforts.\n[10 April 2023] Maria expresses empathy and encouragement for John during a difficult time.\n[5 August 2023] Maria expresses empathy and concern for John's situation.\n[3 July 2023] Maria says: Any resources or organizations you know of that could help her out? Thanks!\n[13 August 2023] Maria enjoys spending time with family.\n[1 January 2023] Maria expresses admiration for John's work and mentions the impact of their efforts.\n[9 January 2023] Maria supports John's community initiative and believes in collective action.\n[5 July 2023] John takes care of Maria.\n[25 May 2023] Maria is motivated by working with passionate people.\n[6 March 2023] John acknowledges Maria's impact and expresses interest in understanding how she built connections.\n[18 April 2023] Maria expresses admiration for John's work and shares a positive observation about it.\n[6 May 2023] John thanks Maria for her support and encouragement.\n\n[Relevant Memories]\n(Episodic summaries of past conversations relevant to the current question.)\n[6 March 2023] Maria and John discussed Maria's recent loss and shared stories about their family experiences, including their love for parenting, family activities, and travel memories. They exchanged photos and images of family moments and shared insights about building connections and making a difference through volunteering. Maria expressed gratitude for her support system, while John highlighted the importance of listening and being present in forming meaningful relationships.\n[27 June 2023] Maria and John discussed their experiences with support from family and friends, sharing moments of joy and positivity. Maria mentioned volunteering at a shelter and a special memory with a child who was uplifted by her presence. John acknowledged the importance of kindness and shared his own experience of finding silver linings in tough times.\n[2 April 2023] Maria and John discussed their experiences with poetry and education, sharing their aspirations and community involvement. Maria praised John's dedication to policymaking and community work, while John highlighted the impact of his efforts and the importance of collaboration.\n[18 April 2023] John and Maria discussed their passion for education, infrastructure, and community impact, sharing their experiences of blogging, attending a convention, and volunteering. They emphasized the importance of collective action, inspired by each other's dedication and the positive impact of small acts of kindness.\n[25 February 2023] Maria and John discussed their recent personal experiences and shared insights about positivity, community, and the impact of kindness. Maria mentioned taking a creative writing class and volunteering at a homeless shelter, while John talked about running for office and his experience with community impact. They reflected on the importance of resilience, gratitude, and optimism, and expressed enthusiasm about working together to improve their community.\n[7 April 2023] John and Maria discussed their new yoga class and a 5K charity run. John shared details about his yoga routine and volunteer experience, while Maria talked about her charity run and the impact of community efforts. Both expressed enthusiasm and appreciation for each other's activities.\n\n[Question]\nWhat writing classes has Maria taken?\n\nUse exact words from the retrieved memory whenever possible. Answer concisely.\nOutput JSON: {\"answer\": \"...\"}.", "output": {"answer": "Maria has taken a poetry class and a creative writing class."}}
''')
# Out:
# {"call_type": "call_6_qa", "system_prompt": "You are a helpful assistant answering a question about a multi-session conversation between two named speakers, based on memory.
#
# Node types:
#   State:  A speaker-specific condition that is currently or recently valid and may change over time. It captures the speaker's present stance, ongoing goal, constraint, situation, or preference shift. States are time-bounded and context-sensitive.
#   Trait:  A generalized speaker characteristic that persists across situations and time. It represents recurring dispositions, stable preferences, values, or habitual tendencies. Traits are cross-situational and relatively context-independent.
#   Memory: An episodic summary of what happened during a recent conversation. It captures concrete events, topics, and actions at a particular time, not generalized speaker attributes.
#
# ...
